# %% [markdown]
# <a href="https://colab.research.google.com/github/junaiskv94/Airbnb_bookin_Analysis/blob/main/GitHub_Airbnb_Bookings_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# ## <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# ## <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy.stats import uniform
# %matplotlib inline

# %%
# Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing Dataset
df=pd.read_csv('/content/drive/MyDrive/pandas/Airbnb NYC 2019.csv')

# %% [markdown]
# **DataSet Inspection**

# %%
# First look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# Given file has 48895 rows and 16 columns

# %%
df.size
# Out:
# 782320

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# checking numerical values
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# > Maximum price for the room is $10000 & the minimum price is 0,which means that some rooms are available at free of cost. Median price of the listing is 106,that means fifty percentage of the listings are avaialble below 106.
#
# > The mean price of the room is $152 with SD 240,The high deviation from the mean price indicates for the presence of outliers, hence distribution is right skewed
#
# > The IQR of room price is between $69 and $175.
#
# > The mean number of nights to be booked for a room is 7 .
#
#
# > The max and min of the minimum nights of required for the booking is 1250 and 1 respectively
#
# > The maximum number of reviews available for a listing is 629 and the minimum of zero and with  mean number of 23 reviews and with a median of 5 reviews
#
# >The  maximum number of listings owned by a single host is 327.
#
# > Fifty percentage of the listings have the availabilty of rooms less than 45 days in a year.
# The mean number of availaibilty of rooms in a year is 112 days.

# %%
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# **Missing Data**

# %%
# find the total missing values in each column
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# 16 Missing values in the name ,21 in host_name,10052 each in last_review and reviews_per_month.

# %%
total=df.isnull().sum().sort_values(ascending=False)
percent=((df.isnull().sum()/df.isnull().count())*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# %%
missing_data
# Out:
#                                 Total    Percent
# last_review                     10052  20.558339
# reviews_per_month               10052  20.558339
# host_name                          21   0.042949
# name                               16   0.032723
# id                                  0   0.000000
# host_id                             0   0.000000
# neighbourhood_group                 0   0.000000
# neighbourhood                       0   0.000000
# latitude                            0   0.000000
# longitude                           0   0.000000
# room_type                           0   0.000000
# price                               0   0.000000
# minimum_nights                      0   0.000000
# number_of_reviews                   0   0.000000
# calculated_host_listings_count      0   0.000000
# availability_365                    0   0.000000

# %% [markdown]
# Missing data that has been observed does not require any special treatment. Further, given the nature of our dataset, we can state that columns "name", "host_name" and "laast_review" are irrelevant and insignificant to our data analysis and considering the privacy and ethical issues we drop these columns, while columns "review per month" require very simple handling. For "review per month" we can add 0.0 for missing values.

# %%
# Droping the columns which are not relevent 
df.drop(['host_name','last_review'],axis=1,inplace=True)

# %%
# Replace the missing values in reviews_per_month with zero
df["reviews_per_month"].fillna(0, inplace = True)

# %%
# Examining the changes 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  reviews_per_month               48895 non-null  float64
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# Checking the correltion between all variables
corr = df.corr(method='kendall')
plt.figure(figsize=(16,8))
sns.heatmap(corr, annot=True)

# %%
# Finding  the unique  neighborhood groups
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# There are five unique neighbourhood groups

# %%
# finding the roomtypes
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %% [markdown]
# There are three types of rooms

# %%
#Count of room types
df[['room_type']].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# dtype: int64

# %%
top_host=df['host_id'].value_counts().head(10).reset_index()
top_host.columns=['host_id','listing_count']
top_host
# Out:
#      host_id  listing_count
# 0  219517861            327
# 1  107434423            232
# 2   30283594            121
# 3  137358866            103
# 4   16098958             96
# 5   12243051             96
# 6   61391963             91
# 7   22541573             87
# 8  200380610             65
# 9    7503643             52

# %%
host_plot=sns.barplot(x='host_id',y='listing_count',data=top_host)
host_plot.set_title('Hosts with the most listings ')
host_plot.set_ylabel('Count of listings')
host_plot.set_xlabel('Host IDs')
host_plot.set_xticklabels(host_plot.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '7503643'),
#  Text(0, 0, '12243051'),
#  Text(0, 0, '16098958'),
#  Text(0, 0, '22541573'),
#  Text(0, 0, '30283594'),
#  Text(0, 0, '61391963'),
#  Text(0, 0, '107434423'),
#  Text(0, 0, '137358866'),
#  Text(0, 0, '200380610'),
#  Text(0, 0, '219517861')]

# %%
sub_1=df.loc[df['neighbourhood_group'] == 'Brooklyn']
price_sub1=sub_1[['price']]

# %%
group_price=[]
for groups in list(df['neighbourhood_group'].unique()):
  price_table=df[df['neighbourhood_group']== groups][['price']]
  group_price.append(price_table.describe(percentiles=[.25, .50, .75]))
file=pd.concat([group_price[i] for i in range (len(group_price))],axis=1)  
file.columns=[list(df['neighbourhood_group'].unique())]
file
# Out:
#            Brooklyn     Manhattan        Queens Staten Island        Bronx
# count  20104.000000  21661.000000   5666.000000    373.000000  1091.000000
# mean     124.383207    196.875814     99.517649    114.812332    87.496792
# std      186.873538    291.383183    167.102155    277.620403   106.709349
# min        0.000000      0.000000     10.000000     13.000000     0.000000
# 25%       60.000000     95.000000     50.000000     50.000000    45.000000
# 50%       90.000000    150.000000     75.000000     75.000000    65.000000
# 75%      150.000000    220.000000    110.000000    110.000000    99.000000
# max    10000.000000  10000.000000  10000.000000   5000.000000  2500.000000

# %% [markdown]
# Now taking the listings with price less than 500 in order to remove outliers

# %%
df_price=df[df['price']<500]
df_price
group_price1=[]
for groups in list(df_price['neighbourhood_group'].unique()):
  price_table1=df_price[df_price['neighbourhood_group']== groups][['price']]
  group_price1.append(price_table1.describe(percentiles=[.25, .50, .75]))
file1=pd.concat([group_price1[i] for i in range (len(group_price1))],axis=1)  
file1.columns=[list(df_price['neighbourhood_group'].unique())]
file1
# Out:
#            Brooklyn     Manhattan       Queens Staten Island        Bronx
# count  19825.000000  20756.000000  5630.000000    367.000000  1082.000000
# mean     111.651248    161.106379    92.344583     91.144414    80.969501
# std       73.181876     91.539124    62.462250     63.075143    58.100554
# min        0.000000      0.000000    10.000000     13.000000     0.000000
# 25%       60.000000     91.000000    50.000000     50.000000    45.000000
# 50%       90.000000    143.000000    75.000000     75.000000    65.000000
# 75%      146.000000    200.000000   110.000000    105.500000    99.000000
# max      499.000000    499.000000   499.000000    450.000000   475.000000

# %%
df[df['neighbourhood_group']=='Brooklyn'][['price']]

# %%
price_sub1

# %%
# Find the neighbourhood_group type counts
sns.countplot(df['neighbourhood_group'] )
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.title('neighbourhood group')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'neighbourhood group')

# %%
# Find the differernt room type counts
sns.countplot(df['room_type'] )
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.title('Room Type')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Room Type')

# %%
sns.displot(df['price'], kde=True)

# %%
sns.displot(np.log2(df['price']), kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# Log of price follows normal distribution with mean 152

# %%
df.groupby('room_type').minimum_nights.median().plot(kind='bar',figsize=(18,8))
plt.ylabel('Avg. min nights')
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# Minimum nights of booking required is highest for apartment and least for shared rooms required

# %% [markdown]
# Max number of people prefers one

# %%
sns.displot(np.log(df['number_of_reviews']))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# This may be due less reviews for listings has high minmum number of n8s

# %%
# Finding Top neighbour hoods
top_neighbourhoods=df['neighbourhood'].value_counts().sort_values(ascending=False).reset_index().head(10)
top_neighbourhoods.columns=['neighbourhood','count']
my_plot=sns.barplot(x='neighbourhood',y='count',data=top_neighbourhoods)
my_plot.set_xticklabels(my_plot.get_xticklabels(),rotation=45)
top_neighbourhoods
# Out:
#         neighbourhood  count
# 0        Williamsburg   3920
# 1  Bedford-Stuyvesant   3714
# 2              Harlem   2658
# 3            Bushwick   2465
# 4     Upper West Side   1971
# 5      Hell's Kitchen   1958
# 6        East Village   1853
# 7     Upper East Side   1798
# 8       Crown Heights   1564
# 9             Midtown   1545

# %%
df.groupby('neighbourhood_group')['availability_365'].median()
# Out:
# neighbourhood_group
# Bronx            148.0
# Brooklyn          28.0
# Manhattan         36.0
# Queens            98.0
# Staten Island    219.0
# Name: availability_365, dtype: float64

# %%
# Relation between nirghbour hood and availability 
plt.figure(figsize=(10,10))
ax = sns.boxplot(data=df, x='neighbourhood_group',y='availability_365',palette='plasma')

# %%
df.groupby('room_type')['availability_365'].median()
# Out:
# room_type
# Entire home/apt    42.0
# Private room       45.0
# Shared room        90.0
# Name: availability_365, dtype: float64

# %%
ax = sns.boxplot(data=df, x='room_type',y='availability_365',palette='plasma')

# %%
ax = sns.boxplot(data=df, x='room_type',y='price',palette='plasma')

# %%
df.groupby('room_type').price.median()
# Out:
# room_type
# Entire home/apt    160.0
# Private room        70.0
# Shared room         45.0
# Name: price, dtype: float64

# %%
df.groupby('room_type').price.mean()
# Out:
# room_type
# Entire home/apt    211.794246
# Private room        89.780973
# Shared room         70.127586
# Name: price, dtype: float64

# %%
df.groupby('room_type').price.mean().plot(kind='bar',figsize=(18,8))
plt.ylabel('Avg. price')
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
df.groupby('neighbourhood_group').price.mean()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
df.groupby('neighbourhood_group').price.median()
# Out:
# neighbourhood_group
# Bronx             65.0
# Brooklyn          90.0
# Manhattan        150.0
# Queens            75.0
# Staten Island     75.0
# Name: price, dtype: float64

# %%
df.groupby('neighbourhood_group').price.median()
# Out:
# neighbourhood_group
# Bronx             65.0
# Brooklyn          90.0
# Manhattan        150.0
# Queens            75.0
# Staten Island     75.0
# Name: price, dtype: float64

# %%
df.groupby('neighbourhood_group').price.mean().plot(kind='bar',figsize=(18,8))
plt.ylabel('Avg. price')
plt.show()

# %%
sns.scatterplot(data=df, x="number_of_reviews", y="availability_365",hue='room_type')

# %%
sns.scatterplot(data=df, x="price", y="availability_365",hue='room_type')

# %%
# map of neighbour hoods groups 
plt.figure(figsize=(12,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group)
plt.ioff()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# availibility of nieghbour hoods 
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.availability_365)
plt.ioff()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Distribution of room types in each neighbor hood groups
room_dist=df.groupby(['neighbourhood_group','room_type'])['room_type'].count().unstack()

# %%
room_dist.plot(kind='bar')

# %%
plot=room_dist.plot(kind='pie',subplots=True,figsize=(20,5),autopct='%1.2f%%')

# %%
# room distribution in each nieghbour hood area 
room_dist2=room_dist.T
plot=room_dist2.plot(kind='pie',subplots=True,figsize=(25,15),autopct='%1.2f%%')

# %%
# Finding  the neighborhood belongs to each neighborhood area
neighbourhood_in_neghbourhoodarea=pd.DataFrame(df.groupby('neighbourhood_group')['neighbourhood'].unique()).reset_index()

# %%
neighbourhood_in_neghbourhoodarea
# Out:
#   neighbourhood_group                                      neighbourhood
# 0               Bronx  [Highbridge, Clason Point, Eastchester, Kingsb...
# 1            Brooklyn  [Kensington, Clinton Hill, Bedford-Stuyvesant,...
# 2           Manhattan  [Midtown, Harlem, East Harlem, Murray Hill, He...
# 3              Queens  [Long Island City, Woodside, Flushing, Sunnysi...
# 4       Staten Island  [St. George, Tompkinsville, Emerson Hill, Shor...

# %% [markdown]
# There are a total of five  different neighbourhood groups

# %%
def neighbour_count(neighbors):
  return len(neighbors)

# %%
neighbourhood_in_neghbourhoodarea['number of neighbourhood']=neighbourhood_in_neghbourhoodarea['neighbourhood'].apply(neighbour_count)

# %%
neighbourhood_in_neghbourhoodarea
# Out:
#   neighbourhood_group                                      neighbourhood  \
# 0               Bronx  [Highbridge, Clason Point, Eastchester, Kingsb...
# 1            Brooklyn  [Kensington, Clinton Hill, Bedford-Stuyvesant,...
# 2           Manhattan  [Midtown, Harlem, East Harlem, Murray Hill, He...
# 3              Queens  [Long Island City, Woodside, Flushing, Sunnysi...
# 4       Staten Island  [St. George, Tompkinsville, Emerson Hill, Shor...
#
#    number of neighbourhood
# 0                       48
# 1                       47
# 2                       32
# 3                       51
# 4                       43

# %%
# Finding the total hosts in each neighborhood
area_host_rel=df.groupby('neighbourhood_group')['host_id'].count().reset_index().rename({'host_id':'host_number'},axis='columns')

# %%
area_host_rel
# Out:
#   neighbourhood_group  host_number
# 0               Bronx         1091
# 1            Brooklyn        20104
# 2           Manhattan        21661
# 3              Queens         5666
# 4       Staten Island          373

# %%
# Plot hosts in differet neighbour hood group
sns.barplot(data=area_host_rel, x="neighbourhood_group", y="host_number",palette='plasma').set(title="Hosts  in different neighbourhood_group")
# Out:
# [Text(0.5, 1.0, 'Hosts  in different neighbourhood_group')]

# %%
# Finding the distribution of room_types with different hosts in each neighbour hood group
area_host_roomtype=df.groupby(['neighbourhood_group','room_type'])['host_id'].count().reset_index().rename({'host_id':'host_number'},axis='columns')
area_host_roomtype
# Out:
#    neighbourhood_group        room_type  host_number
# 0                Bronx  Entire home/apt          379
# 1                Bronx     Private room          652
# 2                Bronx      Shared room           60
# 3             Brooklyn  Entire home/apt         9559
# 4             Brooklyn     Private room        10132
# 5             Brooklyn      Shared room          413
# 6            Manhattan  Entire home/apt        13199
# 7            Manhattan     Private room         7982
# 8            Manhattan      Shared room          480
# 9               Queens  Entire home/apt         2096
# 10              Queens     Private room         3372
# 11              Queens      Shared room          198
# 12       Staten Island  Entire home/apt          176
# 13       Staten Island     Private room          188
# 14       Staten Island      Shared room            9

# %%
sns.barplot(data=area_host_roomtype, x="neighbourhood_group", y="host_number",hue="room_type").set(title="Hosts  in different neighbourhood_group")
# Out:
# [Text(0.5, 1.0, 'Hosts  in different neighbourhood_group')]

# %%
plt.pie(area_host_rel['host_number'], labels = area_host_rel['neighbourhood_group'], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fddb0bbcbd0>,
# ...
#  [Text(1.097298498667151, 0.07704547243554677, 'Bronx'),
#   Text(0.15227771312965807, 1.0894087837373085, 'Brooklyn'),
#   Text(-0.6183764501497931, -0.9097310404180681, 'Manhattan'),
#   Text(1.0079616011872188, -0.44046953417018325, 'Queens'),
#   Text(1.0996841146061016, -0.026359971225222757, 'Staten Island')],
#  [Text(0.5985264538184459, 0.04202480314666187, '2.23%'),
#   Text(0.0830605707979953, 0.5942229729476227, '41.12%'),
#   Text(-0.33729624553625076, -0.496216931137128, '44.30%'),
#   Text(0.5497972370112102, -0.24025610954737264, '11.59%'),
#   Text(0.5998276988760554, -0.014378166122848774, '0.76%')])

# %% [markdown]
# The Manhattana and Brookyln are the neighbourhood groups which  has most number of hosts of host and Staten Island has least number of hosts

# %%
# Encoding the input variables of columns room type and neighbour hood group
df1=df.copy()
df1[['neighbourhood_group', 'room_type']] = df1[['neighbourhood_group', 'room_type']].apply(lambda x: pd.factorize(x)[0])
df1.drop(['id','name','host_id','latitude','longitude','neighbourhood','number_of_reviews'],axis=1,inplace=True)
df1
# Out:
#        neighbourhood_group  room_type  price  minimum_nights  \
# 0                        0          0    149               1
# 1                        1          1    225               1
# 2                        1          0    150               3
# 3                        0          1     89               1
# 4                        1          1     80              10
# ...                    ...        ...    ...             ...
# 48890                    0          0     70               2
# 48891                    0          0     40               4
# 48892                    1          1    115              10
# 48893                    1          2     55               1
# 48894                    1          0     90               7
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# ...

# %%
#Get Correlation between different variables
corr = df1.corr(method='kendall')
plt.figure(figsize=(20,12))
sns.heatmap(corr, annot=True)

# %%
# Finding relation between room_type and price
plt.figure(figsize=(10,10))
ax = sns.boxplot(data=df, x='room_type',y='price',palette='plasma',hue='room_type')

# %% [markdown]
# We have few extreme values(outliers),so we can screen the price below 500 to have a better visualisation

# %%
df2=df[df['price']<500]
plt.figure(figsize=(10,10))
ax = sns.boxplot(data=df2, x='room_type',y='price',palette='plasma',hue='room_type')

# %%
# find relation between price and neighbour hood
plt.figure(figsize=(10,10))
ax = sns.boxplot(data=df2, x='neighbourhood_group',y='price',palette='plasma',hue='neighbourhood_group')

# %%
# find relation between price and neighbour hood
plt.figure(figsize=(10,10))
ax = sns.boxplot(data=df2, x='neighbourhood_group',y='price',palette='plasma',hue='room_type')

# %%
# FInd the relationship between reviews per month and availability
plt.figure(figsize=(10,10))
ax = sns.jointplot(data=df2,x='availability_365',y='reviews_per_month',palette='plasma')

# %%
# find the relation between price and host listing
sns.jointplot(data=df, x="price", y="calculated_host_listings_count")

# %%
place_neibour_price_range=df.groupby('neighbourhood')['price'].mean().reset_index().sort_values(by='price',ascending=False)
place_neibour_price_range.set_index('neighbourhood',inplace=True)

# %%
neighbourhoods_highprice=place_neibour_price_range.head(30)
neighbourhoods_lower_price=place_neibour_price_range.tail(30)

# %%
place_neibour_price_range.describe()
# Out:
#             price
# count  221.000000
# mean   133.248493
# std     94.530766
# min     47.333333
# 25%     81.730769
# 50%    101.800000
# 75%    152.714286
# max    800.000000

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)
plt.rcParams["figure.figsize"] = [10, 6]

# %%
# neighbour hood with having high price
neighbourhoods_highprice['price'].plot(kind="barh",width = 0.5)
plt.title(" neighbourhoods with high prices")
plt.ylabel("neighbourhood")
plt.xlabel("Avg_price")
# Out:
# Text(0.5, 0, 'Avg_price')

# %%
neighbourhoods_lower_price['price'].plot(kind="barh",width = 0.5)
plt.title("neighbourhoods with low prices")
plt.ylabel("neighbourhood")
plt.xlabel("Avg_price")
# Out:
# Text(0.5, 0, 'Avg_price')

# %%
# finding most listed hotel
hotel_area=df.groupby(['name','neighbourhood_group'])['calculated_host_listings_count'].count().reset_index()
hotel_area.sort_values(by ='calculated_host_listings_count',ascending=False).head(20)
# Out:
#                                                     name neighbourhood_group  \
# 22162                                     Hillside Hotel              Queens
# 9367                                  Brooklyn Apartment            Brooklyn
# 25841                   Loft Suite @ The Box House Hotel            Brooklyn
# 4591          Artsy Private BR in Fort Greene Cumberland            Brooklyn
# 29851                                     Name not given           Manhattan
# 14611                            Cozy Brooklyn Apartment            Brooklyn
# 22441                                Home away from home              Queens
# 5779                       Beautiful Brooklyn Brownstone            Brooklyn
# 34474                       Private room in Williamsburg            Brooklyn
# 34372                           Private room in Brooklyn            Brooklyn
# 21777                                         Harlem Gem           Manhattan
# ...

# %%
area_review=df.groupby(['name','price','neighbourhood_group'])['room_type'].count().reset_index()
price_reveiws=area_review.sort_values(by ='price')
price_reveiws
# Out:
#                                                     name  price  \
# 0                      1 Bed Apt in Utopic Williamsburg     155
# 32442             Perfect Getaway in West Village Duplex    180
# 32443                    Perfect Grand Central apartment    325
# 32444                            Perfect Greenpoint Loft     60
# 32445               Perfect Greenwich village studio apt    130
# ...                                                  ...    ...
# 22505                                     Hillside Hotel    165
# 23550  IN MINT CONDITION-STUDIOS EAST 44TH/UNITED NAT...    175
# 4619          Artsy Private BR in Fort Greene Cumberland     48
# 26224                   Loft Suite @ The Box House Hotel    199
# 22504                                     Hillside Hotel    135
#
#       neighbourhood_group  room_type
# 0                Brooklyn          1
# 32442           Manhattan          1
# 32443           Manhattan          1
# 32444            Brooklyn          1
# ...

# %%
area_review=df.groupby(['name','neighbourhood_group','price','minimum_nights'])['number_of_reviews'].count().reset_index()
area_review.sort_values(by ='price',ascending=False).head(20)
# Out:
#                                                     name neighbourhood_group  \
# 27223    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 20219                Furnished room in Astoria apartment              Queens
# 1112                                 1-BR Lincoln Center           Manhattan
# 2224   2br - The Heart of NYC: Manhattans Lower East ...           Manhattan
# 36168                Quiet, Clean, Lit @ LES & Chinatown           Manhattan
# 41061                                 Spanish Harlem Apt           Manhattan
# 7091   Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho           Manhattan
# 19732                                      Film Location            Brooklyn
# 18363          East 72nd Townhouse by (Hidden by Airbnb)           Manhattan
# 20461                               Gem of east Flatbush            Brooklyn
# 2748                 70' Luxury MotorYacht on the Hudson           Manhattan
# ...

# %%
area_review.sort_values(by ='number_of_reviews',ascending=False).head(20)
# Out:
#                                                     name neighbourhood_group  \
# 22522                                     Hillside Hotel              Queens
# 26246                   Loft Suite @ The Box House Hotel            Brooklyn
# 4619          Artsy Private BR in Fort Greene Cumberland            Brooklyn
# 23571  IN MINT CONDITION-STUDIOS EAST 44TH/UNITED NAT...           Manhattan
# 22523                                     Hillside Hotel              Queens
# 29592     Modern, Cozy Apt Share for Young Professionals            Brooklyn
# 26959  Luminous Modern Apt Share for Young Professionals            Brooklyn
# 26245                       Loft Suite @ Box House Hotel            Brooklyn
# 19884  Four Points by Sheraton New York Downtown-7 Ni...           Manhattan
# 24013                                          Kan house              Queens
# 2839     A CLASSIC NYC NEIGHBORHOOD-EAST 86TH/5TH AVENUE           Manhattan
# ...

# %%
# Finding the price range  of each room type in every neighbour hood group
df.groupby(['neighbourhood_group','room_type']).agg({'price':['min','max','mean','median']}).reset_index()
# Out:
#    neighbourhood_group        room_type price
#                                           min    max        mean median
# 0                Bronx  Entire home/apt    28   1000  127.506596  100.0
# 1                Bronx     Private room     0   2500   66.788344   53.5
# 2                Bronx      Shared room    20    800   59.800000   40.0
# 3             Brooklyn  Entire home/apt     0  10000  178.327545  145.0
# 4             Brooklyn     Private room     0   7500   76.500099   65.0
# 5             Brooklyn      Shared room     0    725   50.527845   36.0
# 6            Manhattan  Entire home/apt     0  10000  249.239109  191.0
# 7            Manhattan     Private room    10   9999  116.776622   90.0
# 8            Manhattan      Shared room    10   1000   88.977083   69.0
# 9               Queens  Entire home/apt    10   2600  147.050573  120.0
# 10              Queens     Private room    10  10000   71.762456   60.0
# ...
